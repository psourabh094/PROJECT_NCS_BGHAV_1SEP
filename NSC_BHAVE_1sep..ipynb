# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
bd = pd.read_csv('E:\\DATA SETS\\cm01SEP2023bhav.csv')

# %%
bd.head()
# Out:
#        SYMBOL SERIES    OPEN    HIGH     LOW   CLOSE    LAST  PREVCLOSE  \
# 0  1018GS2026     GS  130.00  130.00  130.00  130.00  130.00     130.00
# 1  182D051023     TB   99.16   99.16   99.16   99.16   99.16      99.15
# 2  182D091123     TB   98.55   98.55   98.55   98.55   98.55      98.50
# 3  182D110124     TB   97.20   97.20   97.20   97.20   97.20      96.91
# 4  182D140923     TB   99.57   99.79   99.49   99.70   99.70      99.47
#
#    TOTTRDQTY  TOTTRDVAL  TIMESTAMP  TOTALTRADES          ISIN
# 0          5      650.0  01-Sep-23            1  IN0020010081
# 1        100     9916.0  01-Sep-23            1  IN002023Y011
# 2        100     9855.0  01-Sep-23            1  IN002023Y060
# 3       9000   874800.0  01-Sep-23            2  IN002023Y151
# 4       2900   288744.0  01-Sep-23            9  IN002022Y518

# %%
bd
# Out:
#           SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0     1018GS2026     GS   130.00   130.00   130.00   130.00   130.00
# 1     182D051023     TB    99.16    99.16    99.16    99.16    99.16
# 2     182D091123     TB    98.55    98.55    98.55    98.55    98.55
# 3     182D110124     TB    97.20    97.20    97.20    97.20    97.20
# 4     182D140923     TB    99.57    99.79    99.49    99.70    99.70
# ...          ...    ...      ...      ...      ...      ...      ...
# 2493        ZOTA     EQ   435.00   446.45   433.00   437.20   437.00
# 2494       ZUARI     EQ   162.75   163.35   160.25   160.95   161.00
# 2495    ZUARIIND     EQ   142.20   144.60   142.20   143.85   143.90
# 2496   ZYDUSLIFE     EQ   625.85   629.10   612.60   613.95   615.00
# 2497   ZYDUSWELL     EQ  1651.00  1672.00  1625.00  1633.45  1628.15
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL  TIMESTAMP  TOTALTRADES          ISIN
# ...

# %%
bd.isnull().sum()
# Out:
# SYMBOL         0
# SERIES         6
# OPEN           0
# HIGH           0
# LOW            0
# CLOSE          0
# LAST           0
# PREVCLOSE      0
# TOTTRDQTY      0
# TOTTRDVAL      0
# TIMESTAMP      0
# TOTALTRADES    0
# ISIN           0
# dtype: int64

# %%
bd.describe()
# Out:
#                 OPEN           HIGH            LOW          CLOSE  \
# count    2498.000000    2498.000000    2498.000000    2498.000000
# mean      839.367546     849.436857     829.993963     839.789764
# std      3004.970596    3018.176356    2961.338710    2981.506534
# min         0.350000       0.400000       0.350000       0.400000
# 25%        69.762500      71.125000      68.550000      70.275000
# 50%       225.450000     232.200000     221.255000     228.600000
# 75%       762.437500     774.325000     749.750000     761.362500
# max    109500.000000  109500.000000  107559.050000  107984.150000
#
#                 LAST      PREVCLOSE     TOTTRDQTY     TOTTRDVAL    TOTALTRADES
# count    2498.000000    2498.000000  2.498000e+03  2.498000e+03    2498.000000
# mean      839.464564     837.283775  2.234763e+06  3.473066e+08   11066.719776
# std      2982.981972    2991.494804  1.952541e+07  1.481222e+09   29260.353114
# ...

# %%
bd.columns
# Out:
# Index(['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST', 'PREVCLOSE',
#        'TOTTRDQTY', 'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES', 'ISIN'],
#       dtype='object')

# %%
bd.shape
# Out:
# (2498, 13)

# %%
bd.dropna(how='any', inplace=True)

# %%
bd.shape
# Out:
# (2492, 13)

# %%
word_to_search = 'EQ'

# %%
filtered_bd = bd[bd.apply(lambda row: row.astype(str).str.contains(word_to_search).any(), axis=1)]

# %%
filtered_bd.to_csv('filtered_data.csv', index=False)

# %%
df = pd.read_csv('filtered_data.csv')

# %%
df
# Out:
#           SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0     21STCENMGM     EQ     18.75     19.05     18.40     18.75     18.75
# 1         360ONE     EQ    494.70    494.70    475.00    477.60    475.00
# 2      3IINFOLTD     EQ     32.75     33.35     32.50     32.80     32.75
# 3        3MINDIA     EQ  31400.00  31400.00  31001.00  31151.35  31199.95
# 4         5PAISA     EQ    452.50    465.00    445.50    449.45    450.00
# ...          ...    ...       ...       ...       ...       ...       ...
# 1683        ZOTA     EQ    435.00    446.45    433.00    437.20    437.00
# 1684       ZUARI     EQ    162.75    163.35    160.25    160.95    161.00
# 1685    ZUARIIND     EQ    142.20    144.60    142.20    143.85    143.90
# 1686   ZYDUSLIFE     EQ    625.85    629.10    612.60    613.95    615.00
# 1687   ZYDUSWELL     EQ   1651.00   1672.00   1625.00   1633.45   1628.15
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL  TIMESTAMP  TOTALTRADES          ISIN
# ...

# %%
# most of high valume, brakout,
